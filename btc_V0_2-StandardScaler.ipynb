# %% [markdown]
# # lib

# %%
import pickle
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler , StandardScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # preprocessing data

# %%
import pandas_ta as ta

# %%
path_to_file = "btc.csv"

# %%
btc = pd.read_csv(path_to_file, skiprows=1)
btc = btc[::-1]
# btc = btc[2100:]
btc = btc.astype({'date': 'datetime64'}).set_index('date')
btc = btc.drop(['unix', 'symbol','Volume USD'], axis=1)

btc.head()
# Out:
#               open    high     low   close  Volume BTC
# date
# 2014-11-28  363.59  381.34  360.57  376.28  3220878.18
# 2014-11-29  376.42  386.60  372.25  376.72  2746157.05
# 2014-11-30  376.57  381.99  373.32  373.34  1145566.61
# 2014-12-01  376.40  382.31  373.03  378.39  2520662.37
# 2014-12-02  378.39  382.86  375.23  379.25  2593576.46

# %%
# btc_input_df_datetype.set_index("time").close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
btc.close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
# Out:
# <AxesSubplot:title={'center':'Bitcoin Weighted Price'}, xlabel='date'>

# %%
btc['close_log'] =  np.log(btc['close'])
btc['diff1_log'] = btc['close_log'].diff()
btc['diff7_log'] = btc['close_log'].diff(7)
btc['diff30_log'] = btc['close_log'].diff(30)
btc['diff1'] = btc['close'].diff()
btc['diff7'] = btc['close'].diff(7)
btc['diff30'] = btc['close'].diff(30)
# btc['reverse_diff'] = btc['close'].shift(1) + btc['diff']
btc['rsi'] = ta.rsi(btc['close'],length=14)
btc['mom'] = ta.mom(btc['close'],length=10)
btc['target_log'] = btc['close_log'].shift(-1)
btc['target'] = btc['close'].shift(-1)
btc = btc.dropna()

# %%
btc.tail()
# Out:
#                 open      high       low     close    Volume BTC  close_log  \
# date
# 2022-05-09  34051.20  34224.35  30015.00  30082.00   7631.121662  10.311682
# 2022-05-10  30066.48  32650.00  29731.03  30999.97   7402.302313  10.341742
# 2022-05-11  31002.27  32148.15  27757.77  29000.00  11180.848836  10.275051
# 2022-05-12  28999.99  30090.70  25401.05  28896.19  16578.810599  10.271465
# 2022-05-13  28932.69  30974.60  28686.37  29238.81   6010.273639  10.283252
#
#             diff1_log  diff7_log  diff30_log    diff1     diff7    diff30  \
# date
# 2022-05-09  -0.123183  -0.247277   -0.351861 -3943.50  -8439.01 -12685.89
# 2022-05-10   0.030059  -0.196468   -0.306865   917.97  -6729.98 -11133.88
# 2022-05-11  -0.066690  -0.313683   -0.309634 -1999.97 -10685.23 -10524.86
# 2022-05-12  -0.003586  -0.234532   -0.327603  -103.81  -7637.74 -11201.27
# 2022-05-13   0.011787  -0.208556   -0.341672   342.62  -6780.41 -11908.93
#
#                   rsi      mom  target_log    target
# date
# 2022-05-09  24.506606 -8511.42   10.341742  30999.97
# 2022-05-10  28.604810 -6639.83   10.275051  29000.00
# 2022-05-11  25.373064 -9488.34   10.271465  28896.19
# 2022-05-12  25.213830 -9624.82   10.283252  29238.81
# 2022-05-13  26.845615 -8491.14   10.288993  29407.14

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaler_t = MinMaxScaler(feature_range=(0, 1))
# scaler_tlog = MinMaxScaler(feature_range=(0, 1))
# StandardScaler
scaler = StandardScaler()
scaler_t = StandardScaler()
scaler_tlog = StandardScaler()


btc.diff1_log = scaler.fit_transform(btc.diff1_log.values.reshape(-1,1))
btc.diff7_log = scaler.fit_transform(btc.diff7_log.values.reshape(-1,1))
btc.diff30_log = scaler.fit_transform(btc.diff30_log.values.reshape(-1,1))
btc.diff1 = scaler.fit_transform(btc.diff1.values.reshape(-1,1))
btc.diff7 = scaler.fit_transform(btc.diff7.values.reshape(-1,1))
btc.diff30 = scaler.fit_transform(btc.diff30.values.reshape(-1,1))
btc.rsi = scaler.fit_transform(btc.rsi.values.reshape(-1,1))
btc.mom = scaler.fit_transform(btc.mom.values.reshape(-1,1))

btc.close = scaler_t.fit_transform(btc.close.values.reshape(-1,1))
btc.target = scaler_t.transform(btc.target.values.reshape(-1,1))

btc.close_log = scaler_tlog.fit_transform(btc.close_log.values.reshape(-1,1))
btc.target_log = scaler_tlog.transform(btc.target_log.values.reshape(-1,1))

# %%
prediction_days = 60

df_train_= btc[:][:len(btc)-prediction_days]#values.reshape(-1,1)

df_test_= btc[:][len(btc)-prediction_days:]#.values.reshape(-1,1)

# %% [markdown]
# # creat data lstm

# %%
df_train_.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'Volume BTC', 'close_log', 'diff1_log',
#        'diff7_log', 'diff30_log', 'diff1', 'diff7', 'diff30', 'rsi', 'mom',
#        'target_log', 'target'],
#       dtype='object')

# %%
df_train = df_train_[:][['close_log', 'target_log']]
df_test = df_test_[:][['close_log', 'target_log']]
df_test.head(2)
# Out:
#             close_log  target_log
# date
# 2022-03-15   1.296125     1.32249
# 2022-03-16   1.322490     1.31997

# %%
# many to one

look_back_ = 5

from collections import deque
def dataset_generator_lstm(dataset, look_back=look_back_):
  sequential_data = [] 
  prev_days = deque(maxlen=look_back)
  for i in dataset.values:
    prev_days.append([n for n in i[:-1]])
    if len(prev_days) == look_back:  
      sequential_data.append([np.array(prev_days), i[-1]])
  dataX=[]
  dataY=[]
  for seq, target in sequential_data: 
    dataX.append(seq) 
    dataY.append(target) 
  return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(df_train)
trainX, trainY = trainX[2100:], trainY[2100:]
testX, testY = dataset_generator_lstm(df_test)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testY: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (530, 5, 1)
# trainY:  (530,)
# testY:  (56, 5, 1)
# testY (56,)

# %% [markdown]
# # train

# %%
regressor = Sequential()

regressor.add(LSTM(units = 256, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))
# 

regressor.add(LSTM(units = 128, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2])))
# regressor.add(LSTM(units = 64, return_sequences = True, input_shape = (trainX.shape[1], trainX.shape[2])))

regressor.add(Dropout(0.2))


regressor.add(Dense(units = 1))

regressor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 256)            264192
#
#  dropout_2 (Dropout)         (None, 5, 256)            0
#
#  lstm_3 (LSTM)               (None, 128)               197120
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 461,441
# Trainable params: 461,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'my_best_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]


# history = regressor.fit(trainX[(len(trainY)-370):], trainY[(len(trainY)-370):], batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
history = regressor.fit(trainX, trainY, batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
# Out:
# Epoch 1/300
# 4/5 [=======================>......] - ETA: 0s - loss: 1.5306
# Epoch 1: loss improved from inf to 1.52361, saving model to my_best_model.hdf5
# 5/5 [==============================] - 2s 94ms/step - loss: 1.5236 - val_loss: 1.2153
# Epoch 2/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.9813
# Epoch 2: loss improved from 1.52361 to 0.97127, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 0.9713 - val_loss: 0.4723
# Epoch 3/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2020
# Epoch 3: loss improved from 0.97127 to 0.19574, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1957 - val_loss: 0.1405
# Epoch 4/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2842
# Epoch 4: loss did not improve from 0.19574
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2777 - val_loss: 0.0154
# Epoch 5/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0193
# Epoch 5: loss improved from 0.19574 to 0.02904, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0290 - val_loss: 0.0809
# Epoch 6/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.1084
# Epoch 6: loss did not improve from 0.02904
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1076 - val_loss: 0.0769
# Epoch 7/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0592
# Epoch 7: loss did not improve from 0.02904
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0580 - val_loss: 0.0034
# Epoch 8/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0169
# Epoch 8: loss improved from 0.02904 to 0.01696, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0170 - val_loss: 0.0254
# Epoch 9/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0352
# Epoch 9: loss did not improve from 0.01696
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0347 - val_loss: 0.0073
# Epoch 10/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0134
# Epoch 10: loss improved from 0.01696 to 0.01345, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0134 - val_loss: 0.0041
# Epoch 11/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0202
# Epoch 11: loss did not improve from 0.01345
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0202 - val_loss: 0.0057
# Epoch 12/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0159
# Epoch 12: loss did not improve from 0.01345
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0157 - val_loss: 0.0012
# Epoch 13/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0135
# Epoch 13: loss improved from 0.01345 to 0.01338, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0134 - val_loss: 0.0028
# Epoch 14/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0135
# Epoch 14: loss did not improve from 0.01338
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0136 - val_loss: 0.0012
# Epoch 15/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0121
# Epoch 15: loss improved from 0.01338 to 0.01209, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0121 - val_loss: 0.0021
# Epoch 16/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0139
# Epoch 16: loss did not improve from 0.01209
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0141 - val_loss: 0.0012
# Epoch 17/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0120
# Epoch 17: loss improved from 0.01209 to 0.01192, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0119 - val_loss: 0.0026
# Epoch 18/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0127
# Epoch 18: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0125 - val_loss: 0.0012
# Epoch 19/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0115
# Epoch 19: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0120 - val_loss: 0.0019
# Epoch 20/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0133
# Epoch 20: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0133 - val_loss: 0.0012
# Epoch 21/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0123
# Epoch 21: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0125 - val_loss: 0.0021
# Epoch 22/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0134
# Epoch 22: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0128 - val_loss: 0.0013
# Epoch 23/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0126
# Epoch 23: loss did not improve from 0.01192
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0123 - val_loss: 0.0012
# Epoch 24/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0115
# Epoch 24: loss improved from 0.01192 to 0.01157, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0116 - val_loss: 0.0012
# Epoch 25/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0126
# Epoch 25: loss did not improve from 0.01157
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0126 - val_loss: 0.0011
# Epoch 26/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0116
# Epoch 26: loss improved from 0.01157 to 0.01148, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0115 - val_loss: 0.0012
# Epoch 27/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0123
# Epoch 27: loss did not improve from 0.01148
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0123 - val_loss: 0.0013
# Epoch 28/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0128
# Epoch 28: loss did not improve from 0.01148
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0126 - val_loss: 0.0012
# Epoch 29/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0114
# Epoch 29: loss did not improve from 0.01148
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0116 - val_loss: 0.0011
# Epoch 30/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0115
# Epoch 30: loss improved from 0.01148 to 0.01148, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0115 - val_loss: 0.0012
# Epoch 31/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0120
# Epoch 31: loss did not improve from 0.01148
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0118 - val_loss: 0.0012
# Epoch 32/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0116
# Epoch 32: loss did not improve from 0.01148
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0118 - val_loss: 0.0011
# Epoch 33/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0111
# Epoch 33: loss improved from 0.01148 to 0.01099, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 34/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0116
# Epoch 34: loss did not improve from 0.01099
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0115 - val_loss: 0.0012
# Epoch 35/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0117
# Epoch 35: loss did not improve from 0.01099
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0116 - val_loss: 0.0017
# Epoch 36/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0109
# Epoch 36: loss improved from 0.01099 to 0.01080, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0108 - val_loss: 0.0011
# Epoch 37/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0119
# Epoch 37: loss did not improve from 0.01080
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0121 - val_loss: 0.0012
# Epoch 38/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0105
# Epoch 38: loss improved from 0.01080 to 0.01050, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0105 - val_loss: 0.0017
# Epoch 39/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0128
# Epoch 39: loss did not improve from 0.01050
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0129 - val_loss: 0.0012
# Epoch 40/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0108
# Epoch 40: loss did not improve from 0.01050
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0111 - val_loss: 0.0014
# Epoch 41/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0132
# Epoch 41: loss did not improve from 0.01050
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0127 - val_loss: 0.0013
# Epoch 42/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0103
# Epoch 42: loss improved from 0.01050 to 0.01020, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0102 - val_loss: 0.0012
# Epoch 43/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0132
# Epoch 43: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0130 - val_loss: 0.0016
# Epoch 44/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0108
# Epoch 44: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 45/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0110
# Epoch 45: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0108 - val_loss: 0.0024
# Epoch 46/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0111
# Epoch 46: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 47/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0108
# Epoch 47: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0109 - val_loss: 0.0011
# Epoch 48/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0122
# Epoch 48: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0122 - val_loss: 0.0015
# Epoch 49/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0109
# Epoch 49: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 50/300
# 5/5 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 50: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0112 - val_loss: 0.0011
# Epoch 51/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0103
# Epoch 51: loss did not improve from 0.01020
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0106 - val_loss: 0.0012
# Epoch 52/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0101
# Epoch 52: loss improved from 0.01020 to 0.01008, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0101 - val_loss: 0.0011
# Epoch 53/300
# 3/5 [=================>............] - ETA: 0s - loss: 0.0097
# Epoch 53: loss did not improve from 0.01008
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0102 - val_loss: 0.0011
# Epoch 54/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0114
# Epoch 54: loss did not improve from 0.01008
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0113 - val_loss: 0.0011
# Epoch 55/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0111
# Epoch 55: loss did not improve from 0.01008
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 56/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0106
# Epoch 56: loss did not improve from 0.01008
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0107 - val_loss: 0.0011
# Epoch 57/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0100
# Epoch 57: loss improved from 0.01008 to 0.00981, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0098 - val_loss: 0.0012
# Epoch 58/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0103
# Epoch 58: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0103 - val_loss: 0.0011
# Epoch 59/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0109
# Epoch 59: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0110 - val_loss: 0.0011
# Epoch 60/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0103
# Epoch 60: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0104 - val_loss: 0.0012
# Epoch 61/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0106
# Epoch 61: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0105 - val_loss: 0.0012
# Epoch 62/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0104
# Epoch 62: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0105 - val_loss: 0.0011
# Epoch 63/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0101
# Epoch 63: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0102 - val_loss: 0.0013
# Epoch 64/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0100
# Epoch 64: loss did not improve from 0.00981
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0011
# Epoch 65/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0094
# Epoch 65: loss improved from 0.00981 to 0.00927, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0093 - val_loss: 0.0012
# Epoch 66/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0119
# Epoch 66: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0118 - val_loss: 0.0015
# Epoch 67/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0113
# Epoch 67: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0111 - val_loss: 0.0012
# Epoch 68/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0100
# Epoch 68: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0011
# Epoch 69/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0093
# Epoch 69: loss improved from 0.00927 to 0.00927, saving model to my_best_model.hdf5
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0093 - val_loss: 0.0011
# Epoch 70/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0113
# Epoch 70: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0113 - val_loss: 0.0012
# Epoch 71/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0103
# Epoch 71: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0104 - val_loss: 0.0011
# Epoch 72/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0101
# Epoch 72: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0011
# Epoch 73/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0104
# Epoch 73: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0106 - val_loss: 0.0015
# Epoch 74/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0113
# Epoch 74: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0116 - val_loss: 0.0014
# Epoch 75/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0108
# Epoch 75: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0108 - val_loss: 0.0011
# Epoch 76/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0113
# Epoch 76: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0115 - val_loss: 0.0012
# Epoch 77/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0106
# Epoch 77: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0106 - val_loss: 0.0011
# Epoch 78/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0101
# Epoch 78: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0011
# Epoch 79/300
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0099
# Epoch 79: loss did not improve from 0.00927
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0101 - val_loss: 0.0010

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model('my_best_model.hdf5')

# %% [markdown]
# # test test

# %%
plt.figure(figsize=(16,7))

# log
predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)
predicted_btc_price_test_data = scaler_tlog.inverse_transform(predicted_btc_price_test_data.reshape(-1, 1))
test_actual = scaler_tlog.inverse_transform(testY.reshape(-1, 1))

plt.plot(np.exp(predicted_btc_price_test_data), 'r', marker='.', label='Predicted Test')
plt.plot(np.exp(test_actual), marker='.', label='Actual Test')

# # manoal
# predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)
# predicted_btc_price_test_data = scaler_t.inverse_transform(predicted_btc_price_test_data.reshape(-1, 1))
# test_actual = scaler_t.inverse_transform(testY.reshape(-1, 1))

# plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')
# plt.plot(test_actual, marker='.', label='Actual Test')
# plt.legend()
# plt.show()

# %% [markdown]
# # test train

# %%
plt.figure(figsize=(24,7))

# log
predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)
predicted_btc_price_train_data = scaler_tlog.inverse_transform(predicted_btc_price_train_data.reshape(-1, 1))
train_actual = scaler_tlog.inverse_transform(trainY.reshape(-1, 1))

plt.plot(np.exp(predicted_btc_price_train_data), 'r', marker='.', label='Predicted Test')
plt.plot(np.exp(train_actual), marker='.', label='Actual Test')

# # manoal
# predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)
# predicted_btc_price_train_data = scaler_t.inverse_transform(predicted_btc_price_train_data.reshape(-1, 1))
# train_actual = scaler_t.inverse_transform(trainY.reshape(-1, 1))

# plt.plot(predicted_btc_price_train_data, 'r', marker='.', label='Predicted Test')
# plt.plot(train_actual, marker='.', label='Actual Test')
# plt.legend()
# plt.show()

# %% [markdown]
# # future

# %% [markdown]
# ###### many to one

# %%
from collections import deque
SEQ_LEN=len(testX[-1])
prev_days = deque(maxlen=SEQ_LEN)

for i in range(-len(testX[-1]),0,1):
  # prev_days.append(scaler.transform(test_actual[i].reshape(-1,1)))
  prev_days.append(testX[-1][i])

# %%
y_p_ = []
future_len = 180
for i in range(future_len):
  x__ = np.array(prev_days).reshape(-1,1).astype(np.float32)

  per = model_from_saved_checkpoint.predict(np.array([x__,x__]))[0].reshape(-1,1)
  prev_days.append(per.reshape(-1,1))
  y_p_.append(per.reshape(-1,1))
  # y_p_.append(scaler.inverse_transform(per.reshape(-1,1)))

# %%
# log
y_p_ = scaler_tlog.inverse_transform(np.array(y_p_).reshape(-1, 1))
# manoal
# y_p_ = scaler_t.inverse_transform(np.array(y_p_).reshape(-1, 1))

# %% [markdown]
# ###### plot future

# %%
actual = np.concatenate((train_actual,test_actual))
predicted_btc_price = np.concatenate((predicted_btc_price_train_data, predicted_btc_price_test_data, np.array(y_p_).reshape(-1,1)), axis=0)

# %%
plt.figure(figsize=(24,7))

# log
plt.plot(np.exp(actual),'y', marker='.', label='Actual Train')
plt.plot(np.exp(predicted_btc_price), 'g', marker='.', label='Predicted Train')
# manoal
# plt.plot(actual,'y', marker='.', label='Actual Train')
# plt.plot(predicted_btc_price, 'g', marker='.', label='Predicted Train')


plt.legend()
plt.show()
