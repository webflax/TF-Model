# %% [markdown]
# # lib

# %%
import pickle
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler , StandardScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, ConvLSTM1D, Conv1D, Concatenate, Bidirectional
from tensorflow.keras.layers import LSTM , BatchNormalization, AveragePooling1D, Flatten, GRU, SimpleRNNM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # preprocessing data

# %%
import pandas_ta as ta

# %%
path_to_file = "btc.csv"

# %%
btc = pd.read_csv(path_to_file, skiprows=1)
btc = btc[::-1]
# btc = btc[2100:]
btc = btc.astype({'date': 'datetime64'}).set_index('date')
btc = btc.drop(['unix', 'symbol','Volume USD'], axis=1)

btc.head()
# Out:
#               open    high     low   close  Volume BTC
# date
# 2014-11-28  363.59  381.34  360.57  376.28  3220878.18
# 2014-11-29  376.42  386.60  372.25  376.72  2746157.05
# 2014-11-30  376.57  381.99  373.32  373.34  1145566.61
# 2014-12-01  376.40  382.31  373.03  378.39  2520662.37
# 2014-12-02  378.39  382.86  375.23  379.25  2593576.46

# %%
# btc_input_df_datetype.set_index("time").close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
btc.close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
# Out:
# <AxesSubplot:title={'center':'Bitcoin Weighted Price'}, xlabel='date'>

# %%
btc['close_log'] =  np.log(btc['close'])
btc['diff1_log'] = btc['close_log'].diff()
btc['diff7_log'] = btc['close_log'].diff(7)
btc['diff30_log'] = btc['close_log'].diff(30)
btc['diff1'] = btc['close'].diff()
btc['diff7'] = btc['close'].diff(7)
btc['diff30'] = btc['close'].diff(30)
# btc['reverse_diff'] = btc['close'].shift(1) + btc['diff']
btc['rsi'] = ta.rsi(btc['close'],length=14)
btc['mom'] = ta.mom(btc['close'],length=10)
btc['target_log'] = btc['close_log'].shift(-1)
btc['target'] = btc['close'].shift(-1)
btc = btc.dropna()

# %%
btc.tail()
# Out:
#                 open      high       low     close    Volume BTC  close_log  \
# date
# 2022-05-09  34051.20  34224.35  30015.00  30082.00   7631.121662  10.311682
# 2022-05-10  30066.48  32650.00  29731.03  30999.97   7402.302313  10.341742
# 2022-05-11  31002.27  32148.15  27757.77  29000.00  11180.848836  10.275051
# 2022-05-12  28999.99  30090.70  25401.05  28896.19  16578.810599  10.271465
# 2022-05-13  28932.69  30974.60  28686.37  29238.81   6010.273639  10.283252
#
#             diff1_log  diff7_log  diff30_log    diff1     diff7    diff30  \
# date
# 2022-05-09  -0.123183  -0.247277   -0.351861 -3943.50  -8439.01 -12685.89
# 2022-05-10   0.030059  -0.196468   -0.306865   917.97  -6729.98 -11133.88
# 2022-05-11  -0.066690  -0.313683   -0.309634 -1999.97 -10685.23 -10524.86
# 2022-05-12  -0.003586  -0.234532   -0.327603  -103.81  -7637.74 -11201.27
# 2022-05-13   0.011787  -0.208556   -0.341672   342.62  -6780.41 -11908.93
#
#                   rsi      mom  target_log    target
# date
# 2022-05-09  24.506606 -8511.42   10.341742  30999.97
# 2022-05-10  28.604810 -6639.83   10.275051  29000.00
# 2022-05-11  25.373064 -9488.34   10.271465  28896.19
# 2022-05-12  25.213830 -9624.82   10.283252  29238.81
# 2022-05-13  26.845615 -8491.14   10.288993  29407.14

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler_t = MinMaxScaler(feature_range=(0, 1))
scaler_tlog = MinMaxScaler(feature_range=(0, 1))
# # StandardScaler
# scaler = StandardScaler()
# scaler_t = StandardScaler()
# scaler_tlog = StandardScaler()


btc.diff1_log = scaler.fit_transform(btc.diff1_log.values.reshape(-1,1))
btc.diff7_log = scaler.fit_transform(btc.diff7_log.values.reshape(-1,1))
btc.diff30_log = scaler.fit_transform(btc.diff30_log.values.reshape(-1,1))
btc.diff1 = scaler.fit_transform(btc.diff1.values.reshape(-1,1))
btc.diff7 = scaler.fit_transform(btc.diff7.values.reshape(-1,1))
btc.diff30 = scaler.fit_transform(btc.diff30.values.reshape(-1,1))
btc.rsi = scaler.fit_transform(btc.rsi.values.reshape(-1,1))
btc.mom = scaler.fit_transform(btc.mom.values.reshape(-1,1))

btc.close = scaler_t.fit_transform(btc.close.values.reshape(-1,1))
btc.target = scaler_t.transform(btc.target.values.reshape(-1,1))

btc.close_log = scaler_tlog.fit_transform(btc.close_log.values.reshape(-1,1))
btc.target_log = scaler_tlog.transform(btc.target_log.values.reshape(-1,1))

# %%
prediction_days = 60

df_train_= btc[:][:len(btc)-prediction_days]#values.reshape(-1,1)

df_test_= btc[:][len(btc)-prediction_days:]#.values.reshape(-1,1)

# %% [markdown]
# # creat data lstm

# %%
df_train_.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'Volume BTC', 'close_log', 'diff1_log',
#        'diff7_log', 'diff30_log', 'diff1', 'diff7', 'diff30', 'rsi', 'mom',
#        'target_log', 'target'],
#       dtype='object')

# %%
df_train = df_train_[:][['open', 'high', 'low', 'close', 'Volume BTC', 'target']]
df_test = df_test_[:][['open', 'high', 'low', 'close', 'Volume BTC', 'target']]
df_test.head(2)
# Out:
#                 open      high       low     close   Volume BTC    target
# date
# 2022-03-15  39688.55  39896.13  38142.35  0.580748  1638.684030  0.608050
# 2022-03-16  39302.80  41693.97  38865.67  0.608050  5987.103889  0.605386

# %%
# many to one

look_back_ = 5

from collections import deque
def dataset_generator_lstm(dataset, look_back=look_back_):
    sequential_data = [] 
    prev_days = deque(maxlen=look_back)
    for i in dataset.values:
        prev_days.append([n for n in i[:-1]])
        if len(prev_days) == look_back:  
            target = i[-1] / prev_days[0][3]
            sequential_data.append([np.array(prev_days), target])
    dataX=[]
    dataY=[]
    for seq, target in sequential_data: 
        dataX.append(seq) 
        dataY.append(target) 
    return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(df_train)
trainX, trainY = trainX[2100:], trainY[2100:]
testX, testY = dataset_generator_lstm(df_test)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testY: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (530, 5, 5)
# trainY:  (530,)
# testY:  (56, 5, 5)
# testY (56,)

# %% [markdown]
# # train

# %%
regressor = Sequential()

regressor.add(LSTM(units = 256,return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))
# 

regressor.add(LSTM(units = 128, input_shape = (trainX.shape[1], trainX.shape[2])))
# regressor.add(LSTM(units = 64, return_sequences = True, input_shape = (trainX.shape[1], trainX.shape[2])))

regressor.add(Dropout(0.2))


regressor.add(Dense(units = 1))

regressor.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 256)            268288
#
#  dropout_2 (Dropout)         (None, 5, 256)            0
#
#  lstm_3 (LSTM)               (None, 128)               197120
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 465,537
# Trainable params: 465,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'my_best_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

# history = regressor.fit(trainX[(len(trainY)-370):], trainY[(len(trainY)-370):], batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
history = regressor.fit(trainX, trainY, batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY))#, callbacks=callbacks)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 3s 180ms/step - loss: 0.4545 - val_loss: 0.3414
# Epoch 2/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3025 - val_loss: 0.0770
# Epoch 3/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1467 - val_loss: 0.0451
# Epoch 4/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0344 - val_loss: 0.0388
# Epoch 5/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0554 - val_loss: 0.0448
# Epoch 6/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0298 - val_loss: 0.0053
# Epoch 7/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0310 - val_loss: 0.0072
# Epoch 8/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0311 - val_loss: 0.0100
# Epoch 9/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0248 - val_loss: 0.0192
# Epoch 10/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0265 - val_loss: 0.0091
# Epoch 11/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0253 - val_loss: 0.0057
# Epoch 12/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0218 - val_loss: 0.0076
# Epoch 13/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0212 - val_loss: 0.0139
# Epoch 14/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0199 - val_loss: 0.0094
# Epoch 15/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0202 - val_loss: 0.0063
# Epoch 16/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0196 - val_loss: 0.0082
# Epoch 17/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0184 - val_loss: 0.0111
# Epoch 18/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0200 - val_loss: 0.0081
# Epoch 19/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0180 - val_loss: 0.0082
# Epoch 20/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0166 - val_loss: 0.0105
# Epoch 21/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0181 - val_loss: 0.0096
# Epoch 22/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0163 - val_loss: 0.0070
# Epoch 23/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0184 - val_loss: 0.0083
# Epoch 24/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0181 - val_loss: 0.0109
# Epoch 25/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0163 - val_loss: 0.0075
# Epoch 26/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0168 - val_loss: 0.0076
# Epoch 27/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0168 - val_loss: 0.0093
# Epoch 28/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0156 - val_loss: 0.0093
# Epoch 29/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0169 - val_loss: 0.0072
# Epoch 30/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0159 - val_loss: 0.0072
# Epoch 31/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0167 - val_loss: 0.0090
# Epoch 32/300
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0150 - val_loss: 0.0084
# Epoch 33/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0143 - val_loss: 0.0068
# Epoch 34/300
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0142 - val_loss: 0.0088
# Epoch 35/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0139 - val_loss: 0.0085
# Epoch 36/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0136 - val_loss: 0.0075
# Epoch 37/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0142 - val_loss: 0.0071
# Epoch 38/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0148 - val_loss: 0.0099
# Epoch 39/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0133 - val_loss: 0.0085
# Epoch 40/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0141 - val_loss: 0.0069
# Epoch 41/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0126 - val_loss: 0.0091
# Epoch 42/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0129 - val_loss: 0.0077
# Epoch 43/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0136 - val_loss: 0.0072
# Epoch 44/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0146 - val_loss: 0.0127
# Epoch 45/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0127 - val_loss: 0.0069
# Epoch 46/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0132 - val_loss: 0.0072
# Epoch 47/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0125 - val_loss: 0.0103
# Epoch 48/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0123 - val_loss: 0.0064
# Epoch 49/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0131 - val_loss: 0.0088
# Epoch 50/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0127 - val_loss: 0.0105
# Epoch 51/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0128 - val_loss: 0.0071
# Epoch 52/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0121 - val_loss: 0.0076
# Epoch 53/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0110 - val_loss: 0.0102
# Epoch 54/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0122 - val_loss: 0.0072
# Epoch 55/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0116 - val_loss: 0.0075
# Epoch 56/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0110 - val_loss: 0.0080
# Epoch 57/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0117 - val_loss: 0.0077
# Epoch 58/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0114 - val_loss: 0.0080
# Epoch 59/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0121 - val_loss: 0.0087
# Epoch 60/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0117 - val_loss: 0.0082
# Epoch 61/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0108 - val_loss: 0.0087
# Epoch 62/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0108 - val_loss: 0.0083
# Epoch 63/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0122 - val_loss: 0.0075
# Epoch 64/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0110 - val_loss: 0.0075
# Epoch 65/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0111 - val_loss: 0.0093
# Epoch 66/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0114 - val_loss: 0.0076
# Epoch 67/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0104 - val_loss: 0.0073
# Epoch 68/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0094
# Epoch 69/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0113 - val_loss: 0.0074
# Epoch 70/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0103 - val_loss: 0.0077
# Epoch 71/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0118 - val_loss: 0.0086
# Epoch 72/300
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0112 - val_loss: 0.0087
# Epoch 73/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0107 - val_loss: 0.0067
# Epoch 74/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0113 - val_loss: 0.0083
# Epoch 75/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0111 - val_loss: 0.0086
# Epoch 76/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0107 - val_loss: 0.0075
# Epoch 77/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0107 - val_loss: 0.0081
# Epoch 78/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0112 - val_loss: 0.0082
# Epoch 79/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 80/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0109 - val_loss: 0.0090
# Epoch 81/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 82/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0085
# Epoch 83/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0113 - val_loss: 0.0081
# Epoch 84/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0110 - val_loss: 0.0080
# Epoch 85/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0105 - val_loss: 0.0072
# Epoch 86/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 87/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0109 - val_loss: 0.0089
# Epoch 88/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0109 - val_loss: 0.0072
# Epoch 89/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 90/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0105 - val_loss: 0.0087
# Epoch 91/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0071
# Epoch 92/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 93/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0099 - val_loss: 0.0081
# Epoch 94/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0103 - val_loss: 0.0086
# Epoch 95/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0104 - val_loss: 0.0082
# Epoch 96/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0101 - val_loss: 0.0084
# Epoch 97/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0101 - val_loss: 0.0072
# Epoch 98/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - val_loss: 0.0084
# Epoch 99/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0107 - val_loss: 0.0081
# Epoch 100/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0108 - val_loss: 0.0077
# Epoch 101/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0110 - val_loss: 0.0082
# Epoch 102/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0099 - val_loss: 0.0082
# Epoch 103/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0107 - val_loss: 0.0072
# Epoch 104/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0103 - val_loss: 0.0091
# Epoch 105/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0098 - val_loss: 0.0070
# Epoch 106/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0108 - val_loss: 0.0085
# Epoch 107/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0098 - val_loss: 0.0075
# Epoch 108/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0102 - val_loss: 0.0071
# Epoch 109/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0106 - val_loss: 0.0084
# Epoch 110/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0102 - val_loss: 0.0089
# Epoch 111/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0104 - val_loss: 0.0077
# Epoch 112/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0107 - val_loss: 0.0074
# Epoch 113/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0104 - val_loss: 0.0075
# Epoch 114/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0073
# Epoch 115/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0107 - val_loss: 0.0078
# Epoch 116/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0074
# Epoch 117/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0103 - val_loss: 0.0087
# Epoch 118/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0069
# Epoch 119/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0104 - val_loss: 0.0081
# Epoch 120/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0105 - val_loss: 0.0079
# Epoch 121/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 122/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0086
# Epoch 123/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0099 - val_loss: 0.0069
# Epoch 124/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0106 - val_loss: 0.0094
# Epoch 125/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0107 - val_loss: 0.0059
# Epoch 126/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0113 - val_loss: 0.0078
# Epoch 127/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0071
# Epoch 128/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0099 - val_loss: 0.0074
# Epoch 129/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0106 - val_loss: 0.0079
# Epoch 130/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0102 - val_loss: 0.0073
# Epoch 131/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0103 - val_loss: 0.0078
# Epoch 132/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0097 - val_loss: 0.0070
# Epoch 133/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0101 - val_loss: 0.0080
# Epoch 134/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0100 - val_loss: 0.0072
# Epoch 135/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0094 - val_loss: 0.0072
# Epoch 136/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0101 - val_loss: 0.0072
# Epoch 137/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0104 - val_loss: 0.0079
# Epoch 138/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0081
# Epoch 139/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0109 - val_loss: 0.0069
# Epoch 140/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 141/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0104 - val_loss: 0.0072
# Epoch 142/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0102 - val_loss: 0.0073
# Epoch 143/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0099 - val_loss: 0.0075
# Epoch 144/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0103 - val_loss: 0.0074
# Epoch 145/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0102 - val_loss: 0.0065
# Epoch 146/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0090 - val_loss: 0.0066
# Epoch 147/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 148/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0068
# Epoch 149/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0059
# Epoch 150/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0095 - val_loss: 0.0085
# Epoch 151/300
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0101 - val_loss: 0.0065
# Epoch 152/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0106 - val_loss: 0.0080
# Epoch 153/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0102 - val_loss: 0.0071
# Epoch 154/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - val_loss: 0.0069
# Epoch 155/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0102 - val_loss: 0.0083
# Epoch 156/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0098 - val_loss: 0.0063
# Epoch 157/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0104 - val_loss: 0.0085
# Epoch 158/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0099 - val_loss: 0.0068
# Epoch 159/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0106 - val_loss: 0.0081
# Epoch 160/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0097 - val_loss: 0.0064
# Epoch 161/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0099 - val_loss: 0.0080
# Epoch 162/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0094 - val_loss: 0.0075
# Epoch 163/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - val_loss: 0.0074
# Epoch 164/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0102 - val_loss: 0.0077
# Epoch 165/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0072
# Epoch 166/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0087
# Epoch 167/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0061
# Epoch 168/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0094 - val_loss: 0.0084
# Epoch 169/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0106 - val_loss: 0.0067
# Epoch 170/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0102 - val_loss: 0.0085
# Epoch 171/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0064
# Epoch 172/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 173/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0099 - val_loss: 0.0071
# Epoch 174/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0070
# Epoch 175/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0093 - val_loss: 0.0078
# Epoch 176/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0096 - val_loss: 0.0070
# Epoch 177/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0103 - val_loss: 0.0080
# Epoch 178/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0098 - val_loss: 0.0063
# Epoch 179/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0093 - val_loss: 0.0079
# Epoch 180/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 181/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100 - val_loss: 0.0071
# Epoch 182/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0094 - val_loss: 0.0079
# Epoch 183/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0098 - val_loss: 0.0065
# Epoch 184/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0081
# Epoch 185/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0061
# Epoch 186/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - val_loss: 0.0093
# Epoch 187/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0104 - val_loss: 0.0064
# Epoch 188/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0094 - val_loss: 0.0078
# Epoch 189/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0078
# Epoch 190/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0095 - val_loss: 0.0057
# Epoch 191/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 192/300
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0099 - val_loss: 0.0058
# Epoch 193/300
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0111 - val_loss: 0.0084
# Epoch 194/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0064
# Epoch 195/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0097 - val_loss: 0.0073
# Epoch 196/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0099 - val_loss: 0.0064
# Epoch 197/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 198/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0068
# Epoch 199/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 200/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 201/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0109 - val_loss: 0.0063
# Epoch 202/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0103 - val_loss: 0.0077
# Epoch 203/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0096 - val_loss: 0.0064
# Epoch 204/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0101 - val_loss: 0.0067
# Epoch 205/300
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0095 - val_loss: 0.0076
# Epoch 206/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0096 - val_loss: 0.0072
# Epoch 207/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0099 - val_loss: 0.0072
# Epoch 208/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0099 - val_loss: 0.0072
# Epoch 209/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0100 - val_loss: 0.0071
# Epoch 210/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0094 - val_loss: 0.0080
# Epoch 211/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0098 - val_loss: 0.0061
# Epoch 212/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 213/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0099 - val_loss: 0.0056
# Epoch 214/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0088
# Epoch 215/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0108 - val_loss: 0.0065
# Epoch 216/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0076
# Epoch 217/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0067
# Epoch 218/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0100 - val_loss: 0.0067
# Epoch 219/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0106 - val_loss: 0.0079
# Epoch 220/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0102 - val_loss: 0.0059
# Epoch 221/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0097 - val_loss: 0.0091
# Epoch 222/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0098 - val_loss: 0.0061
# Epoch 223/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0099 - val_loss: 0.0072
# Epoch 224/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0094 - val_loss: 0.0070
# Epoch 225/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0090 - val_loss: 0.0077
# Epoch 226/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0098 - val_loss: 0.0066
# Epoch 227/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0101 - val_loss: 0.0064
# Epoch 228/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0098 - val_loss: 0.0082
# Epoch 229/300
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0095 - val_loss: 0.0060
# Epoch 230/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0107 - val_loss: 0.0089
# Epoch 231/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0096 - val_loss: 0.0061
# Epoch 232/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 233/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 234/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 235/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0074
# Epoch 236/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 237/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0066
# Epoch 238/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0094 - val_loss: 0.0074
# Epoch 239/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0098 - val_loss: 0.0068
# Epoch 240/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0088 - val_loss: 0.0074
# Epoch 241/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0095 - val_loss: 0.0068
# Epoch 242/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0077
# Epoch 243/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0090 - val_loss: 0.0075
# Epoch 244/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0091 - val_loss: 0.0064
# Epoch 245/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0071
# Epoch 246/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0099 - val_loss: 0.0068
# Epoch 247/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0091 - val_loss: 0.0070
# Epoch 248/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0100 - val_loss: 0.0069
# Epoch 249/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0102 - val_loss: 0.0076
# Epoch 250/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0096 - val_loss: 0.0066
# Epoch 251/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0083
# Epoch 252/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0069
# Epoch 253/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0071
# Epoch 254/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0091 - val_loss: 0.0067
# Epoch 255/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0078
# Epoch 256/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 257/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0104 - val_loss: 0.0076
# Epoch 258/300
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0099 - val_loss: 0.0062
# Epoch 259/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0109 - val_loss: 0.0086
# Epoch 260/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0096 - val_loss: 0.0062
# Epoch 261/300
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0105 - val_loss: 0.0072
# Epoch 262/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0097 - val_loss: 0.0084
# Epoch 263/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0104 - val_loss: 0.0060
# Epoch 264/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0091 - val_loss: 0.0076
# Epoch 265/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0096 - val_loss: 0.0066
# Epoch 266/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0098 - val_loss: 0.0071
# Epoch 267/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0097 - val_loss: 0.0066
# Epoch 268/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 269/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0101 - val_loss: 0.0064
# Epoch 270/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0101 - val_loss: 0.0075
# Epoch 271/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0096 - val_loss: 0.0070
# Epoch 272/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 273/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0088 - val_loss: 0.0067
# Epoch 274/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0103 - val_loss: 0.0064
# Epoch 275/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0106 - val_loss: 0.0079
# Epoch 276/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0097 - val_loss: 0.0067
# Epoch 277/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 278/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0090 - val_loss: 0.0061
# Epoch 279/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - val_loss: 0.0073
# Epoch 280/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0103 - val_loss: 0.0068
# Epoch 281/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0096 - val_loss: 0.0066
# Epoch 282/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0074
# Epoch 283/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0092 - val_loss: 0.0062
# Epoch 284/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0096 - val_loss: 0.0065
# Epoch 285/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0099 - val_loss: 0.0068
# Epoch 286/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0089 - val_loss: 0.0070
# Epoch 287/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0070
# Epoch 288/300
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0092 - val_loss: 0.0064
# Epoch 289/300
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0102 - val_loss: 0.0079
# Epoch 290/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0101 - val_loss: 0.0060
# Epoch 291/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0101 - val_loss: 0.0076
# Epoch 292/300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0101 - val_loss: 0.0062
# Epoch 293/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 294/300
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0092 - val_loss: 0.0059
# Epoch 295/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0101 - val_loss: 0.0090
# Epoch 296/300
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0089 - val_loss: 0.0058
# Epoch 297/300
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0100 - val_loss: 0.0079
# Epoch 298/300
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0092 - val_loss: 0.0061
# Epoch 299/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0074
# Epoch 300/300
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0094 - val_loss: 0.0073

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model('my_best_model.hdf5')

# %% [markdown]
# # test test

# %%
plt.figure(figsize=(16,7))

predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)
testY_ = testY.copy()
for i in range(len(predicted_btc_price_test_data)):
    predicted_btc_price_test_data[i] = scaler_t.inverse_transform(np.array(predicted_btc_price_test_data[i] * testX[i][0][3]).reshape(-1,1))
    testY_[i] = scaler_t.inverse_transform(np.array(testY[i] * testX[i][0][3]).reshape(-1,1))
    
plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')
plt.plot(testY_, marker='.', label='Actual Test')

# %% [markdown]
# # test train

# %%
plt.figure(figsize=(24,7))

predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)
trainY_ =trainY.copy()
for i in range(len(predicted_btc_price_train_data)):
    predicted_btc_price_train_data[i] = scaler_t.inverse_transform(np.array(predicted_btc_price_train_data[i] * trainX[i][0][3]).reshape(-1,1))
    trainY_[i] = scaler_t.inverse_transform(np.array(trainY[i] * trainX[i][0][3]).reshape(-1,1))


plt.plot(predicted_btc_price_train_data, 'r', marker='.', label='Predicted Test')
plt.plot(trainY_, marker='.', label='Actual Test')

# %% [markdown]
# # future

# %% [markdown]
# ###### many to one

# %%
from collections import deque
SEQ_LEN=len(testX[-1])
prev_days = deque(maxlen=SEQ_LEN)

for i in range(-len(testX[-1]),0,1):
  # prev_days.append(scaler.transform(test_actual[i].reshape(-1,1)))
  prev_days.append(testX[-1][i])

# %%
y_p_ = []
future_len = 180
for i in range(future_len):
  x__ = np.array(prev_days).reshape(-1,1).astype(np.float32)

  per = model_from_saved_checkpoint.predict(np.array([x__,x__]))[0].reshape(-1,1)
  prev_days.append(per.reshape(-1,1))
  y_p_.append(per.reshape(-1,1))
  # y_p_.append(scaler.inverse_transform(per.reshape(-1,1)))

# %%
# log
y_p_ = scaler_tlog.inverse_transform(np.array(y_p_).reshape(-1, 1))
# manoal
# y_p_ = scaler_t.inverse_transform(np.array(y_p_).reshape(-1, 1))

# %% [markdown]
# ###### plot future

# %%
actual = np.concatenate((train_actual,test_actual))
predicted_btc_price = np.concatenate((predicted_btc_price_train_data, predicted_btc_price_test_data, np.array(y_p_).reshape(-1,1)), axis=0)

# %%
plt.figure(figsize=(24,7))

# log
plt.plot(np.exp(actual),'y', marker='.', label='Actual Train')
plt.plot(np.exp(predicted_btc_price), 'g', marker='.', label='Predicted Train')
# manoal
# plt.plot(actual,'y', marker='.', label='Actual Train')
# plt.plot(predicted_btc_price, 'g', marker='.', label='Predicted Train')


plt.legend()
plt.show()
