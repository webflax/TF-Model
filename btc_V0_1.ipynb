# %% [markdown]
# # lib

# %%
import pickle
import warnings
warnings.filterwarnings('ignore')
import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler , StandardScaler

from itertools import product
import statsmodels.api as sm

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM

from itertools import cycle
import plotly.offline as py
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # preprocessing data

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      |████████████████████████████████| 115 kB 5.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_ta) (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_ta) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_ta) (1.15.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218923 sha256=508d44f928aba3910e628aeac3f59d799ab80344c3ae54033446e058d5e00548
#   Stored in directory: /root/.cache/pip/wheels/0b/81/f0/cca85757840e4616a2c6b9fe12569d97d324c27cac60724c58
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0

# %%
import pandas_ta as ta

# %%
from google.colab import drive
drive.mount('/content/drive')
path_to_file = "./drive/MyDrive/btc_ohlc_Oct_2015_to_Oct_2021.csv"
# Out:
# Mounted at /content/drive

# %%
btc_input_df = pd.read_csv(path_to_file)
btc_input_df.tail()
# Out:
#                         time     low    high    open   close    volume
# 3113271  2015-10-27 00:04:00  287.07  287.07  287.07  287.07   0.08610
# 3113272  2015-10-27 00:03:00  287.08  287.09  287.08  287.09   0.55440
# 3113273  2015-10-27 00:02:00  286.89  287.10  287.10  286.89  72.40320
# 3113274  2015-10-27 00:01:00  287.09  287.09  287.09  287.09   0.82276
# 3113275  2015-10-27 00:00:00  287.10  287.10  287.10  287.10   0.53620

# %%
btc_input_df_datetype = btc_input_df.astype({'time': 'datetime64'})
btc_input_df_datetype['close_log'] = np.log(btc_input_df_datetype['close'])

# %%
btc_input_df_datetype.drop(2381238,axis=0,inplace=True)
btc_input_df_datetype['close_log'][btc_input_df_datetype['close']<4]
# Out:
# Series([], Name: close_log, dtype: float64)

# %%
# btc_input_df_datetype.set_index("time").close.plot(figsize=(24,7), title="Bitcoin Weighted Price")
btc_input_df_datetype.set_index("time").close_log.plot(figsize=(24,7), title="Bitcoin Weighted Price")

# %%
btc_input_df_datetype['date'] = pd.to_datetime(btc_input_df_datetype['time'],unit='s').dt.date

display(btc_input_df_datetype.head())

group = btc_input_df_datetype.groupby('date')

btc_closing_price_groupby_date = group['close_log'].mean()

display(btc_closing_price_groupby_date.head(10))
# Out:
#                  time       low      high      open     close    volume  \
# 0 2021-10-30 03:00:00  61868.81  61920.00  61888.18  61919.98  2.946079
# 1 2021-10-30 02:59:00  61882.74  61912.67  61903.16  61882.74  2.942357
# 2 2021-10-30 02:58:00  61854.82  61907.96  61854.82  61903.15  3.047848
# 3 2021-10-30 02:57:00  61848.04  61883.02  61883.01  61851.39  3.381070
# 4 2021-10-30 02:56:00  61879.33  61925.42  61907.47  61882.28  5.663128
#
#    close_log        date
# 0  11.033598  2021-10-30
# 1  11.032997  2021-10-30
# 2  11.033326  2021-10-30
# 3  11.032490  2021-10-30
# 4  11.032989  2021-10-30
# date
# 2015-10-27    5.679741
# 2015-10-28    5.710364
# 2015-10-29    5.738202
# 2015-10-30    5.788838
# 2015-10-31    5.780111
# 2015-11-01    5.766747
# 2015-11-02    5.826106
# 2015-11-03    5.957086
# 2015-11-04    6.107486
# 2015-11-05    5.991228
# Name: close_log, dtype: float64

# %%
btc = pd.DataFrame()
btc['close_log'] =  group['close_log'].mean()
btc['diff1_log'] = btc['close_log'].diff()
btc['diff7_log'] = btc['close_log'].diff(7)
btc['diff30_log'] = btc['close_log'].diff(30)
btc['close'] =  group['close'].mean()
btc['diff1'] = btc['close'].diff()
btc['diff7'] = btc['close'].diff(7)
btc['diff30'] = btc['close'].diff(30)
# btc['reverse_diff'] = btc['close'].shift(1) + btc['diff']
btc['rsi'] = ta.rsi(btc['close'],length=14)
btc['mom'] = ta.mom(btc['close'],length=10)
btc['target_log'] = btc['close_log'].shift(-1)
btc['target'] = btc['close'].shift(-1)
btc = btc.dropna()

# %%
btc.tail()
# Out:
#             close_log  diff1_log  diff7_log  diff30_log         close  \
# date
# 2021-10-25  11.044651   0.030810   0.013115    0.385202  62611.015403
# 2021-10-26  11.039727  -0.004924  -0.006909    0.375525  62304.201403
# 2021-10-27  10.993767  -0.045959  -0.087671    0.312790  59508.951285
# 2021-10-28  11.006138   0.012371  -0.065424    0.362312  60252.358194
# 2021-10-29  11.028101   0.021963  -0.009503    0.386915  61584.211944
#
#                   diff1        diff7        diff30        rsi          mom  \
# date
# 2021-10-25  1901.097458   816.782903  20017.460771  68.402510  2725.561507
# 2021-10-26  -306.814000  -433.183042  19503.145444  67.047933  1028.473299
# 2021-10-27 -2795.250118 -5455.561472  15986.450388  56.140175 -1337.288333
# 2021-10-28   743.406910 -4075.249903  18317.494924  58.092845 -1541.874306
# 2021-10-29  1331.853750  -594.829806  19759.308028  61.407790 -1153.172500
#
#             target_log        target
# date
# 2021-10-25   11.039727  62304.201403
# 2021-10-26   10.993767  59508.951285
# 2021-10-27   11.006138  60252.358194
# 2021-10-28   11.028101  61584.211944
# 2021-10-29   11.035381  62030.562210

# %%
with open('./drive/MyDrive/btc.moh','wb') as f :
    pickle.dump(btc,f)

# %% [markdown]
# # Load data

# %%
from google.colab import drive
drive.mount('/content/drive')
with open('./drive/MyDrive/btc.moh','rb') as f :
    btc = pickle.load(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaler_t = MinMaxScaler(feature_range=(0, 1))
# scaler_tlog = MinMaxScaler(feature_range=(0, 1))
# StandardScaler
scaler = StandardScaler()
scaler_t = StandardScaler()
scaler_tlog = StandardScaler()


btc.diff1_log = scaler.fit_transform(btc.diff1_log.values.reshape(-1,1))
btc.diff7_log = scaler.fit_transform(btc.diff7_log.values.reshape(-1,1))
btc.diff30_log = scaler.fit_transform(btc.diff30_log.values.reshape(-1,1))
btc.diff1 = scaler.fit_transform(btc.diff1.values.reshape(-1,1))
btc.diff7 = scaler.fit_transform(btc.diff7.values.reshape(-1,1))
btc.diff30 = scaler.fit_transform(btc.diff30.values.reshape(-1,1))
btc.rsi = scaler.fit_transform(btc.rsi.values.reshape(-1,1))
btc.mom = scaler.fit_transform(btc.mom.values.reshape(-1,1))

btc.close = scaler_t.fit_transform(btc.close.values.reshape(-1,1))
btc.target = scaler_t.transform(btc.target.values.reshape(-1,1))

btc.close_log = scaler_tlog.fit_transform(btc.close_log.values.reshape(-1,1))
btc.target_log = scaler_tlog.transform(btc.target_log.values.reshape(-1,1))

# %%
prediction_days = 60

df_train_= btc[:][:len(btc)-prediction_days]#values.reshape(-1,1)

df_test_= btc[:][len(btc)-prediction_days:]#.values.reshape(-1,1)

# %%
chosen_col = 'Close'

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['close_log'], label='Train', linewidth=2)
ax.plot(df_test_['close_log'], label='Test', linewidth=2)
ax.set_ylabel('Price log', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['diff1_log'], label='Train', linewidth=2)
ax.plot(df_test_['diff1_log'], label='Test', linewidth=2)
ax.set_ylabel('diff1_log', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['diff7_log'], label='Train', linewidth=2)
ax.plot(df_test_['diff7_log'], label='Test', linewidth=2)
ax.set_ylabel('diff7_log', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['diff30_log'], label='Train', linewidth=2)
ax.plot(df_test_['diff30_log'], label='Test', linewidth=2)
ax.set_ylabel('diff30_log', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['close'], label='Train', linewidth=2)
ax.plot(df_test_['close'], label='Test', linewidth=2)
ax.set_ylabel('Price USD', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['diff1'], label='Train', linewidth=2)
ax.plot(df_test_['diff1'], label='Test', linewidth=2)
ax.set_ylabel('diff1', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['rsi'], label='Train', linewidth=2)
ax.plot(df_test_['rsi'], label='Test', linewidth=2)
ax.set_ylabel('rsi', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

fig, ax = plt.subplots(1, figsize=(24, 7))
ax.plot(df_train_['mom'], label='Train', linewidth=2)
ax.plot(df_test_['mom'], label='Test', linewidth=2)
ax.set_ylabel('mom', fontsize=14)
ax.set_title('', fontsize=16)
ax.legend(loc='best', fontsize=16)

# %% [markdown]
# # creat data lstm

# %%
df_train_.columns
# Out:
# Index(['close_log', 'diff1_log', 'diff7_log', 'diff30_log', 'close', 'diff1',
#        'diff7', 'diff30', 'rsi', 'mom', 'target_log', 'target'],
#       dtype='object')

# %%
df_train = df_train_[:][['close', 'target']]
df_test = df_test_[:][['close', 'target']]
df_test.head(2)
# Out:
#                close    target
# date
# 2021-08-31  2.401847  2.427356
# 2021-09-01  2.427356  2.560316

# %%
# many to one

look_back_ = 5

from collections import deque
def dataset_generator_lstm(dataset, look_back=look_back_):
  sequential_data = [] 
  prev_days = deque(maxlen=look_back)
  for i in dataset.values:
    prev_days.append([n for n in i[:-1]])
    if len(prev_days) == look_back:  
      sequential_data.append([np.array(prev_days), i[-1]])
  dataX=[]
  dataY=[]
  for seq, target in sequential_data: 
    dataX.append(seq) 
    dataY.append(target) 
  return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(df_train)

testX, testY = dataset_generator_lstm(df_test)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testY: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (2101, 5, 1)
# trainY:  (2101,)
# testY:  (56, 5, 1)
# testY (56,)

# %% [markdown]
# # train

# %%
regressor = Sequential()

regressor.add(LSTM(units = 256, activation = 'relu',return_sequences=True, input_shape = (trainX.shape[1], trainX.shape[2])))
regressor.add(Dropout(0.2))
# 

regressor.add(LSTM(units = 128, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2])))
# regressor.add(LSTM(units = 64, return_sequences = True, input_shape = (trainX.shape[1], trainX.shape[2])))

regressor.add(Dropout(0.2))


regressor.add(Dense(units = 1))

regressor.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 5, 256)            264192
#
#  dropout_8 (Dropout)         (None, 5, 256)            0
#
#  lstm_9 (LSTM)               (None, 128)               197120
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 461,441
# Trainable params: 461,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

checkpoint_path = 'my_best_model.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')


earlystopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]


# history = regressor.fit(trainX[(len(trainY)-370):], trainY[(len(trainY)-370):], batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
history = regressor.fit(trainX, trainY, batch_size = 128, epochs = 300, verbose=1, shuffle=False, validation_data=(testX, testY), callbacks=callbacks)
# Out:
# Epoch 1/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6374
# Epoch 1: loss improved from inf to 0.70969, saving model to my_best_model.hdf5
# 17/17 [==============================] - 4s 95ms/step - loss: 0.7097 - val_loss: 6.1933
# Epoch 2/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.2075
# Epoch 2: loss improved from 0.70969 to 0.23301, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 71ms/step - loss: 0.2330 - val_loss: 1.1737
# Epoch 3/300
# 16/17 [===========================>..] - ETA: 0s - loss: 2.9474
# Epoch 3: loss did not improve from 0.23301
# 17/17 [==============================] - 1s 68ms/step - loss: 2.9501 - val_loss: 5.9675
# Epoch 4/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.2702
# Epoch 4: loss did not improve from 0.23301
# 17/17 [==============================] - 1s 72ms/step - loss: 0.3160 - val_loss: 3.8126
# Epoch 5/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.3524
# Epoch 5: loss did not improve from 0.23301
# 17/17 [==============================] - 1s 70ms/step - loss: 0.4052 - val_loss: 4.4051
# Epoch 6/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.2987
# Epoch 6: loss did not improve from 0.23301
# 17/17 [==============================] - 1s 70ms/step - loss: 0.3495 - val_loss: 4.1105
# Epoch 7/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.2586
# Epoch 7: loss did not improve from 0.23301
# 17/17 [==============================] - 1s 69ms/step - loss: 0.3025 - val_loss: 3.4600
# Epoch 8/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.1950
# Epoch 8: loss improved from 0.23301 to 0.22843, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 71ms/step - loss: 0.2284 - val_loss: 2.5061
# Epoch 9/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.1156
# Epoch 9: loss improved from 0.22843 to 0.13735, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 71ms/step - loss: 0.1374 - val_loss: 1.3090
# Epoch 10/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0465
# Epoch 10: loss improved from 0.13735 to 0.05680, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0568 - val_loss: 0.2553
# Epoch 11/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0442
# Epoch 11: loss improved from 0.05680 to 0.04779, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0478 - val_loss: 0.1690
# Epoch 12/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0292
# Epoch 12: loss improved from 0.04779 to 0.03376, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0338 - val_loss: 0.0988
# Epoch 13/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0260
# Epoch 13: loss improved from 0.03376 to 0.03052, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0305 - val_loss: 0.0936
# Epoch 14/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0367
# Epoch 14: loss did not improve from 0.03052
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0399 - val_loss: 0.0943
# Epoch 15/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 15: loss did not improve from 0.03052
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0317 - val_loss: 0.1151
# Epoch 16/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 16: loss improved from 0.03052 to 0.02759, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 78ms/step - loss: 0.0276 - val_loss: 0.0866
# Epoch 17/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0217
# Epoch 17: loss improved from 0.02759 to 0.02480, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0248 - val_loss: 0.0776
# Epoch 18/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0209
# Epoch 18: loss improved from 0.02480 to 0.02375, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0238 - val_loss: 0.0832
# Epoch 19/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 19: loss did not improve from 0.02375
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0248 - val_loss: 0.0790
# Epoch 20/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0197
# Epoch 20: loss improved from 0.02375 to 0.02185, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0219 - val_loss: 0.0726
# Epoch 21/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0224
# Epoch 21: loss did not improve from 0.02185
# 17/17 [==============================] - 1s 68ms/step - loss: 0.0248 - val_loss: 0.0666
# Epoch 22/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0205
# Epoch 22: loss did not improve from 0.02185
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0233 - val_loss: 0.0628
# Epoch 23/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0177
# Epoch 23: loss improved from 0.02185 to 0.02025, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0203 - val_loss: 0.0604
# Epoch 24/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0191
# Epoch 24: loss did not improve from 0.02025
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0208 - val_loss: 0.0548
# Epoch 25/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 25: loss did not improve from 0.02025
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0220 - val_loss: 0.0535
# Epoch 26/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0498
# Epoch 26: loss did not improve from 0.02025
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0502 - val_loss: 0.0993
# Epoch 27/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0680
# Epoch 27: loss did not improve from 0.02025
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0774 - val_loss: 0.4112
# Epoch 28/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0172
# Epoch 28: loss improved from 0.02025 to 0.01980, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0198 - val_loss: 0.0560
# Epoch 29/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0173
# Epoch 29: loss improved from 0.01980 to 0.01954, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0195 - val_loss: 0.0569
# Epoch 30/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 30: loss improved from 0.01954 to 0.01794, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0179 - val_loss: 0.0525
# Epoch 31/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0151
# Epoch 31: loss improved from 0.01794 to 0.01715, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 75ms/step - loss: 0.0172 - val_loss: 0.0519
# Epoch 32/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 32: loss did not improve from 0.01715
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0186 - val_loss: 0.0517
# Epoch 33/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0151
# Epoch 33: loss improved from 0.01715 to 0.01691, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0169 - val_loss: 0.0490
# Epoch 34/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0144
# Epoch 34: loss improved from 0.01691 to 0.01579, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0158 - val_loss: 0.0464
# Epoch 35/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0160
# Epoch 35: loss did not improve from 0.01579
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0177 - val_loss: 0.0465
# Epoch 36/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0192
# Epoch 36: loss did not improve from 0.01579
# 17/17 [==============================] - 1s 68ms/step - loss: 0.0206 - val_loss: 0.0634
# Epoch 37/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0149
# Epoch 37: loss did not improve from 0.01579
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0174 - val_loss: 0.0796
# Epoch 38/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0160
# Epoch 38: loss did not improve from 0.01579
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0169 - val_loss: 0.0457
# Epoch 39/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0133
# Epoch 39: loss improved from 0.01579 to 0.01542, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0154 - val_loss: 0.0475
# Epoch 40/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 40: loss improved from 0.01542 to 0.01484, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 76ms/step - loss: 0.0148 - val_loss: 0.0444
# Epoch 41/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0155
# Epoch 41: loss did not improve from 0.01484
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0177 - val_loss: 0.0452
# Epoch 42/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0130
# Epoch 42: loss improved from 0.01484 to 0.01394, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0139 - val_loss: 0.0443
# Epoch 43/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0156
# Epoch 43: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0169 - val_loss: 0.0416
# Epoch 44/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0163
# Epoch 44: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0176 - val_loss: 0.0424
# Epoch 45/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0146
# Epoch 45: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0171 - val_loss: 0.0640
# Epoch 46/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0194
# Epoch 46: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0206 - val_loss: 0.0441
# Epoch 47/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0208
# Epoch 47: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0229 - val_loss: 0.1026
# Epoch 48/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0135
# Epoch 48: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0144 - val_loss: 0.0412
# Epoch 49/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 49: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 74ms/step - loss: 0.0146 - val_loss: 0.0555
# Epoch 50/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0162
# Epoch 50: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0171 - val_loss: 0.0393
# Epoch 51/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 51: loss did not improve from 0.01394
# 17/17 [==============================] - 1s 73ms/step - loss: 0.0159 - val_loss: 0.0401
# Epoch 52/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0121
# Epoch 52: loss improved from 0.01394 to 0.01346, saving model to my_best_model.hdf5
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0135 - val_loss: 0.0393
# Epoch 53/300
# 17/17 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 53: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0165 - val_loss: 0.0382
# Epoch 54/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0136
# Epoch 54: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0150 - val_loss: 0.0547
# Epoch 55/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0169
# Epoch 55: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0187 - val_loss: 0.0376
# Epoch 56/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0186
# Epoch 56: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 69ms/step - loss: 0.0204 - val_loss: 0.0698
# Epoch 57/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0135
# Epoch 57: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0141 - val_loss: 0.0375
# Epoch 58/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0266
# Epoch 58: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 70ms/step - loss: 0.0270 - val_loss: 0.0461
# Epoch 59/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0249
# Epoch 59: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0260 - val_loss: 0.0498
# Epoch 60/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0267
# Epoch 60: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 72ms/step - loss: 0.0301 - val_loss: 0.1879
# Epoch 61/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0150
# Epoch 61: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0163 - val_loss: 0.0390
# Epoch 62/300
# 16/17 [===========================>..] - ETA: 0s - loss: 0.0162
# Epoch 62: loss did not improve from 0.01346
# 17/17 [==============================] - 1s 71ms/step - loss: 0.0172 - val_loss: 0.0418

# %%
plt.figure(figsize=(16,7))
plt.plot(history.history['loss'], label='train')

plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model_from_saved_checkpoint = load_model(checkpoint_path)

# %% [markdown]
# # test test

# %%
predicted_btc_price_test_data = model_from_saved_checkpoint.predict(testX)

predicted_btc_price_test_data = scaler_t.inverse_transform(predicted_btc_price_test_data.reshape(-1, 1))

test_actual = scaler_t.inverse_transform(testY.reshape(-1, 1))

# %%
plt.figure(figsize=(16,7))

# log
# plt.plot(np.exp(predicted_btc_price_test_data), 'r', marker='.', label='Predicted Test')
# plt.plot(np.exp(test_actual), marker='.', label='Actual Test')

# manoal
plt.plot(predicted_btc_price_test_data, 'r', marker='.', label='Predicted Test')
plt.plot(test_actual, marker='.', label='Actual Test')
plt.legend()
plt.show()

# %% [markdown]
# #test train

# %%
predicted_btc_price_train_data = model_from_saved_checkpoint.predict(trainX)

predicted_btc_price_train_data = scaler_t.inverse_transform(predicted_btc_price_train_data.reshape(-1, 1))

train_actual = scaler_t.inverse_transform(trainY.reshape(-1, 1))

plt.figure(figsize=(24,7))

# log
# plt.plot(np.exp(predicted_btc_price_train_data), 'r', marker='.', label='Predicted Test')
# plt.plot(np.exp(train_actual), marker='.', label='Actual Test')

# manoal
plt.plot(predicted_btc_price_train_data, 'g', marker='.', label='Predicted Train')
plt.plot(train_actual,'y', marker='.', label='Actual Train')

plt.legend()
plt.show()

# %% [markdown]
# # score

# %% [markdown]
# ## log

# %% [markdown]
# ### RMSE - Test Data

# %%
rmse_lstm_test = math.sqrt(mean_squared_error(np.exp(test_actual), np.exp(predicted_btc_price_test_data)))

print('Test RMSE: %.3f' % rmse_lstm_test)

# %% [markdown]
# ### RMSE - Train Data

# %%
rmse_lstm_train = math.sqrt(mean_squared_error(np.exp(train_actual), np.exp(predicted_btc_price_train_data)))

print('Test RMSE: %.3f' % rmse_lstm_train)

# %% [markdown]
# ## manoal

# %% [markdown]
# ### RMSE - Test Data

# %%
rmse_lstm_test = math.sqrt(mean_squared_error(test_actual, predicted_btc_price_test_data))

print('Test RMSE: %.3f' % rmse_lstm_test)
# Out:
# Test RMSE: 2951.213

# %% [markdown]
# ### RMSE - Train Data

# %%
rmse_lstm_train = math.sqrt(mean_squared_error(train_actual, predicted_btc_price_train_data))

print('Test RMSE: %.3f' % rmse_lstm_train)
# Out:
# Test RMSE: 1503.741

# %% [markdown]
# # future

# %% [markdown]
# ###### many to one

# %%
from collections import deque
SEQ_LEN=len(testX[-1])
prev_days = deque(maxlen=SEQ_LEN)

for i in range(-len(testX[-1]),0,1):
  # prev_days.append(scaler.transform(test_actual[i].reshape(-1,1)))
  prev_days.append(testX[-1][i])

# %%
y_p_ = []
for i in range(30):
  x__ = np.array(prev_days).reshape(-1,1).astype(np.float32)

  per = model_from_saved_checkpoint.predict(np.array([x__,x__]))[0].reshape(-1,1)
  prev_days.append(per.reshape(-1,1))
  y_p_.append(per.reshape(-1,1))
  # y_p_.append(scaler.inverse_transform(per.reshape(-1,1)))

# %%
y_p_ = scaler_t.inverse_transform(np.array(y_p_).reshape(-1, 1))

# %% [markdown]
# ###### plot future

# %%
actual = np.concatenate((train_actual,test_actual))
predicted_btc_price = np.concatenate((predicted_btc_price_train_data, predicted_btc_price_test_data, np.array(y_p_).reshape(-1,1)), axis=0)

# %%
plt.figure(figsize=(24,7))

# log
# plt.plot(np.exp(predicted_btc_price), 'g', marker='.', label='Predicted Train')
# plt.plot(np.exp(train_actual),'y', marker='.', label='Actual Train')
# manoal
plt.plot(predicted_btc_price, 'g', marker='.', label='Predicted Train')
plt.plot(actual,'y', marker='.', label='Actual Train')

plt.legend()
plt.show()
